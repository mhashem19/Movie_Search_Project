# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Storing IMDB_movies.csv aquired from Data World.
imdb_file = "data/IMDb_movies.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
imdb_df.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
imdb_mov = ["imdb_title_id", "title", "year", "genre", "duration", "country", "director", "actors","description","avg_vote",
            "budget", "usa_gross_income", "worlwide_gross_income", "votes", "reviews_from_users","reviews_from_critics"]
imdb_trnfmd = imdb_df[imdb_mov].copy()

# %%
# Rename the column headers
imdb_trnfmd = imdb_trnfmd.rename(columns={"imdb_title_id": "title_id",
                                                          "usa_gross_income": "gross_income_usa",
                                                          "worlwide_gross_income": "gross_income_global",
                                                          "reviews_from_users": "user_rating",
                                                        "reviews_from_critics": "critics_reviews"})

# %%
imdb_trnfmd.head()
# Out:
#     title_id                                              title  year  \
# 0  tt0000574                        The Story of the Kelly Gang  1906
# 1  tt0001892                                     Den sorte drøm  1911
# 2  tt0002101                                          Cleopatra  1912
# 3  tt0002130                                          L'Inferno  1911
# 4  tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
#
#                        genre  duration           country  \
# 0    Biography, Crime, Drama        70         Australia
# 1                      Drama        53  Germany, Denmark
# 2             Drama, History       100               USA
# 3  Adventure, Drama, Fantasy        68             Italy
# 4           Biography, Drama        60               USA
#
#                               director  \
# 0                         Charles Tait
# 1                            Urban Gad
# 2                   Charles L. Gaskill
# 3  Francesco Bertolini, Adolfo Padovan
# 4                        Sidney Olcott
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description  avg_vote   budget  \
# 0  True story of notorious Australian outlaw Ned ...       6.1   $ 2250
# 1  Two men of high rank are both wooing the beaut...       5.9      NaN
# 2  The fabled queen of Egypt's affair with Roman ...       5.2  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...       7.0      NaN
# 4  An account of the life of Jesus Christ, based ...       5.7      NaN
#
#   gross_income_usa gross_income_global  votes  user_rating  critics_reviews
# 0              NaN                 NaN    537          7.0              7.0
# 1              NaN                 NaN    171          4.0              2.0
# 2              NaN                 NaN    420         24.0              3.0
# 3              NaN                 NaN   2019         28.0             14.0
# 4              NaN                 NaN    438         12.0              5.0

# %%
# Clean the data by dropping duplicates

imdb_trnfmd.drop_duplicates("title_id", inplace=True)

# Filtering DF by keeping based on year 2000 and up, and Country = 'USA'
imdb_trnfmd = imdb_trnfmd.loc[imdb_trnfmd["year"] >= 2000, :]
imdb_trnfmd = imdb_trnfmd.loc[imdb_trnfmd["country"] == "USA", :]

# Copy of existing dataframe
imdb_movies_df = imdb_trnfmd.copy()

#Dropping NaN Values from whole dataframe

imdb_movies_df = imdb_movies_df.dropna()

# %%
imdb_movies_df.dtypes
# Out:
# title_id                object
# title                   object
# year                     int64
# genre                   object
# duration                 int64
# country                 object
# director                object
# actors                  object
# description             object
# avg_vote               float64
# budget                  object
# gross_income_usa        object
# gross_income_global     object
# votes                    int64
# user_rating            float64
# critics_reviews        float64
# dtype: object

# %%
imdb_movies_df
# Out:
#         title_id                 title  year                      genre  \
# 4115   tt0035423        Kate & Leopold  2001   Comedy, Fantasy, Romance
# 28059  tt0113026       The Fantasticks  2000           Musical, Romance
# 29517  tt0118589               Glitter  2001      Drama, Music, Romance
# 30317  tt0120467                Vulgar  2000     Crime, Drama, Thriller
# 30421  tt0120681             From Hell  2001  Horror, Mystery, Thriller
# ...          ...                   ...   ...                        ...
# 80111  tt8186318             Overcomer  2019               Drama, Sport
# 80277  tt8350360  Annabelle Comes Home  2019  Horror, Mystery, Thriller
# 80858  tt9024106             Unplanned  2019           Biography, Drama
# 80946  tt9134216     Playing with Fire  2019             Comedy, Family
# 81059  tt9354944                  Jexi  2019                     Comedy
#
#        duration country                       director  \
# 4115        118     USA                  James Mangold
# 28059        86     USA                Michael Ritchie
# 29517       104     USA             Vondie Curtis-Hall
# 30317        87     USA                  Bryan Johnson
# 30421       122     USA    Albert Hughes, Allen Hughes
# ...         ...     ...                            ...
# 80111       119     USA                  Alex Kendrick
# 80277       106     USA                 Gary Dauberman
# 80858       109     USA  Chuck Konzelman, Cary Solomon
# 80946        96     USA                   Andy Fickman
# 81059        84     USA         Jon Lucas, Scott Moore
#
#                                                   actors  \
# 4115   Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...
# 28059  Joel Grey, Barnard Hughes, Jean Louisa Kelly, ...
# 29517  Mariah Carey, Max Beesley, Da Brat, Tia Texada...
# 30317  Brian O'Halloran, Bryan Johnson, Jerry Lewkowi...
# 30421  Johnny Depp, Heather Graham, Ian Holm, Robbie ...
# ...                                                  ...
# 80111  Alex Kendrick, Shari Rigby, Ben Davies, Prisci...
# 80277  Vera Farmiga, Patrick Wilson, Mckenna Grace, M...
# 80858  Ashley Bratcher, Brooks Ryan, Robia Scott, Jar...
# 80946  John Cena, Keegan-Michael Key, John Leguizamo,...
# 81059  Adam Devine, Alexandra Shipp, Rose Byrne, Ron ...
#
#                                              description  avg_vote  \
# 4115   An English Duke from 1876 is inadvertedly drag...       6.4
# 28059  A mysterious fair come to a small community in...       5.6
# 29517  A young singer dates a disc jockey who helps h...       2.2
# 30317  A man who performs as a children's birthday pa...       5.3
# 30421  In Victorian-era London, a troubled clairvoyan...       6.8
# ...                                                  ...       ...
# 80111  A high-school basketball coach volunteers to c...       6.7
# 80277  While babysitting the daughter of Ed and Lorra...       5.9
# 80858  All Abby Johnson ever wanted to do was help wo...       5.8
# 80946  A crew of rugged firefighters meet their match...       4.5
# 81059  A comedy about what can happen when you love y...       6.6
#
#            budget gross_income_usa gross_income_global   votes  user_rating  \
# 4115   $ 48000000       $ 47121859          $ 76019048   75298        330.0
# 28059  $ 10000000          $ 49666             $ 49666    1082         70.0
# 29517  $ 22000000        $ 4274407           $ 5271666   20959        314.0
# 30317    $ 120000          $ 15927             $ 15927    3852        119.0
# 30421  $ 35000000       $ 31602566          $ 74558115  141180        546.0
# ...           ...              ...                 ...     ...          ...
# 80111   $ 5000000       $ 34712782          $ 35721533    1510        108.0
# 80277  $ 27000000       $ 74152591         $ 228552591   39872        648.0
# 80858   $ 6000000       $ 19005109          $ 19320481   10783        531.0
# 80946  $ 29900000       $ 18847824          $ 21788746    1067         49.0
# 81059   $ 5000000        $ 6546159           $ 7257918    3674         46.0
#
#        critics_reviews
# 4115             127.0
# 28059             24.0
# 29517             74.0
# 30317             22.0
# 30421            189.0
# ...                ...
# 80111             17.0
# 80277            211.0
# 80858             32.0
# 80946             16.0
# 81059             24.0
#
# [2482 rows x 16 columns]

# %%
# This is commented because we ran this block of code successfully
# Removing $, EUR, AD currency indicators and turn columns into Integer from Object.
imdb_movies_df[imdb_movies_df.columns[10:12]] = imdb_movies_df[imdb_movies_df.columns[10:12]].replace('[$,EUR,AD,AUD,ER]', '', regex=True).astype(int)

# %%
imdb_movies_df.head()
# Out:
#         title_id            title  year                      genre  duration  \
# 4115   tt0035423   Kate & Leopold  2001   Comedy, Fantasy, Romance       118
# 28059  tt0113026  The Fantasticks  2000           Musical, Romance        86
# 29517  tt0118589          Glitter  2001      Drama, Music, Romance       104
# 30317  tt0120467           Vulgar  2000     Crime, Drama, Thriller        87
# 30421  tt0120681        From Hell  2001  Horror, Mystery, Thriller       122
#
#       country                     director  \
# 4115      USA                James Mangold
# 28059     USA              Michael Ritchie
# 29517     USA           Vondie Curtis-Hall
# 30317     USA                Bryan Johnson
# 30421     USA  Albert Hughes, Allen Hughes
#
#                                                   actors  \
# 4115   Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...
# 28059  Joel Grey, Barnard Hughes, Jean Louisa Kelly, ...
# 29517  Mariah Carey, Max Beesley, Da Brat, Tia Texada...
# 30317  Brian O'Halloran, Bryan Johnson, Jerry Lewkowi...
# 30421  Johnny Depp, Heather Graham, Ian Holm, Robbie ...
#
#                                              description  avg_vote    budget  \
# 4115   An English Duke from 1876 is inadvertedly drag...       6.4  48000000
# 28059  A mysterious fair come to a small community in...       5.6  10000000
# 29517  A young singer dates a disc jockey who helps h...       2.2  22000000
# 30317  A man who performs as a children's birthday pa...       5.3    120000
# 30421  In Victorian-era London, a troubled clairvoyan...       6.8  35000000
#
#        gross_income_usa gross_income_global   votes  user_rating  \
# 4115           47121859          $ 76019048   75298        330.0
# 28059             49666             $ 49666    1082         70.0
# 29517           4274407           $ 5271666   20959        314.0
# 30317             15927             $ 15927    3852        119.0
# 30421          31602566          $ 74558115  141180        546.0
#
#        critics_reviews
# 4115             127.0
# 28059             24.0
# 29517             74.0
# 30317             22.0
# 30421            189.0

# %%
# Droping the country column
imdb_movies_df.drop(columns=['country'],inplace = True)
# Droping gross income global column
imdb_movies_df.drop(columns=['gross_income_global'],inplace = True)

# %%
#imdb_movies_df.sort_values(by=['year'])
imdb_movies_df.sort_values(by=['title', 'year'], ascending= True, inplace = True )
# Resetting index
imdb_movies_df.reset_index()
# Out:
#       index   title_id                    title  year  \
# 0     51111  tt1022603     (500) Days of Summer  2009
# 1     52966  tt1179933      10 Cloverfield Lane  2016
# 2     68764  tt3453052    10 Days in a Madhouse  2015
# 3     66239  tt2789014        100 Acres of Hell  2019
# 4     42100  tt0360323              10th & Wolf  2006
# ...     ...        ...                      ...   ...
# 2477  43215  tt0383060                     Zoom  2006
# 2478  66770  tt2948356                 Zootopia  2016
# 2479  45111  tt0429277                Zyzzyx Rd  2006
# 2480  39653  tt0295701                      xXx  2002
# 2481  41086  tt0329774  xXx: State of the Union  2005
#
#                              genre  duration                  director  \
# 0           Comedy, Drama, Romance        95                 Marc Webb
# 1           Drama, Horror, Mystery       103          Dan Trachtenberg
# 2                            Drama       111             Timothy Hines
# 3                   Action, Horror        85           Hank Leigh Hump
# 4           Crime, Drama, Thriller       107             Bobby Moresco
# ...                            ...       ...                       ...
# 2477     Action, Adventure, Comedy        83              Peter Hewitt
# 2478  Animation, Adventure, Comedy       108  Byron Howard, Rich Moore
# 2479        Crime, Drama, Thriller        90               John Penney
# 2480   Action, Adventure, Thriller       124                 Rob Cohen
# 2481      Action, Adventure, Crime       101              Lee Tamahori
#
#                                                  actors  \
# 0     Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...
# 1     John Goodman, Mary Elizabeth Winstead, John Ga...
# 2     Caroline Barry, Christopher Lambert, Kelly LeB...
# 3     Gene Snisky, Jeff Swanton, Jim Roof, Ernest O'...
# 4     James Marsden, Giovanni Ribisi, Brad Renfro, P...
# ...                                                 ...
# 2477  Tim Allen, Courteney Cox, Chevy Chase, Spencer...
# 2478  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...
# 2479  Leo Grillo, Katherine Heigl, Tom Sizemore, Ric...
# 2480  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 2481  Willem Dafoe, Samuel L. Jackson, Ice Cube, Sco...
#
#                                             description  avg_vote     budget  \
# 0     An offbeat romantic comedy about a woman who d...       7.7    7500000
# 1     After getting in a car accident, a woman is he...       7.2   15000000
# 2     In 1887, at age 23, reporter Nellie Bly, worki...       6.7     120000
# 3     When ex pro wrestler Buck Severs travels to an...       2.9      65000
# 4     A former street tough returns to his Philadelp...       6.3    8000000
# ...                                                 ...       ...        ...
# 2477  Former superhero Jack is called back to work t...       4.3   35000000
# 2478  In a city of anthropomorphic animals, a rookie...       8.0  150000000
# 2479  The family man accountant Grant travels to Las...       4.0    2000000
# 2480  An extreme sports athlete, Xander Cage, is rec...       5.9   70000000
# 2481  Darius Stone, a new agent in the xXx program, ...       4.4   60000000
#
#       gross_income_usa   votes  user_rating  critics_reviews
# 0             32391374  448799        563.0            349.0
# 1             72082998  268631        700.0            514.0
# 2                14616    1152         26.0              2.0
# 3                 5152     143         17.0              9.0
# 4                54702    5938         34.0             24.0
# ...                ...     ...          ...              ...
# 2477          11989328   17598        119.0             61.0
# 2478         341268248  396148        642.0            474.0
# 2479                30     930         11.0              1.0
# 2480         142109382  168051        739.0            188.0
# 2481          26873932   64761        228.0             62.0
#
# [2482 rows x 15 columns]

# %%
# keeping only first string of genre
imdb_movies_df["genre"] = imdb_movies_df.genre.str.split(",").str.get(0)

# %%
imdb_movies_df.dtypes
# Out:
# title_id             object
# title                object
# year                  int64
# genre                object
# duration              int64
# director             object
# actors               object
# description          object
# avg_vote            float64
# budget                int32
# gross_income_usa      int32
# votes                 int64
# user_rating         float64
# critics_reviews     float64
# dtype: object

# %%
# Displaying clean final data frame
imdb_movies_df.head()
# Out:
#         title_id                  title  year   genre  duration  \
# 51111  tt1022603   (500) Days of Summer  2009  Comedy        95
# 52966  tt1179933    10 Cloverfield Lane  2016   Drama       103
# 68764  tt3453052  10 Days in a Madhouse  2015   Drama       111
# 66239  tt2789014      100 Acres of Hell  2019  Action        85
# 42100  tt0360323            10th & Wolf  2006   Crime       107
#
#                director                                             actors  \
# 51111         Marc Webb  Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...
# 52966  Dan Trachtenberg  John Goodman, Mary Elizabeth Winstead, John Ga...
# 68764     Timothy Hines  Caroline Barry, Christopher Lambert, Kelly LeB...
# 66239   Hank Leigh Hump  Gene Snisky, Jeff Swanton, Jim Roof, Ernest O'...
# 42100     Bobby Moresco  James Marsden, Giovanni Ribisi, Brad Renfro, P...
#
#                                              description  avg_vote    budget  \
# 51111  An offbeat romantic comedy about a woman who d...       7.7   7500000
# 52966  After getting in a car accident, a woman is he...       7.2  15000000
# 68764  In 1887, at age 23, reporter Nellie Bly, worki...       6.7    120000
# 66239  When ex pro wrestler Buck Severs travels to an...       2.9     65000
# 42100  A former street tough returns to his Philadelp...       6.3   8000000
#
#        gross_income_usa   votes  user_rating  critics_reviews
# 51111          32391374  448799        563.0            349.0
# 52966          72082998  268631        700.0            514.0
# 68764             14616    1152         26.0              2.0
# 66239              5152     143         17.0              9.0
# 42100             54702    5938         34.0             24.0

# %%
# Stop......Please read carefully.

# %%
# Please Create New Database in pgAdmin (final_project_db) and " table (imdb_movies)

# %%
# Connecting to local database 
ETL_connection_string = "mario:12345@localhost:5432/final_project_db"
engine = create_engine(f'postgresql://{ETL_connection_string}')

# %%
# Pulling tables from database
engine.table_names()
# Out:
# ['imdb_movies']

# %%
# Below code worked and loaded successfully into pgAdmin Database table. 
imdb_movies_df.to_sql(name='imdb_movies', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the customer_name table
pd.read_sql_query('select * from imdb_movies', con=engine).head()
# Out:
#     title_id                  title  year   genre  duration          director  \
# 0  tt1022603   (500) Days of Summer  2009  Comedy        95         Marc Webb
# 1  tt1179933    10 Cloverfield Lane  2016   Drama       103  Dan Trachtenberg
# 2  tt3453052  10 Days in a Madhouse  2015   Drama       111     Timothy Hines
# 3  tt2789014      100 Acres of Hell  2019  Action        85   Hank Leigh Hump
# 4  tt0360323            10th & Wolf  2006   Crime       107     Bobby Moresco
#
#                                               actors  \
# 0  Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...
# 1  John Goodman, Mary Elizabeth Winstead, John Ga...
# 2  Caroline Barry, Christopher Lambert, Kelly LeB...
# 3  Gene Snisky, Jeff Swanton, Jim Roof, Ernest O'...
# 4  James Marsden, Giovanni Ribisi, Brad Renfro, P...
#
#                                          description  avg_vote    budget  \
# 0  An offbeat romantic comedy about a woman who d...       7.7   7500000
# 1  After getting in a car accident, a woman is he...       7.2  15000000
# 2  In 1887, at age 23, reporter Nellie Bly, worki...       6.7    120000
# 3  When ex pro wrestler Buck Severs travels to an...       2.9     65000
# 4  A former street tough returns to his Philadelp...       6.3   8000000
#
#    gross_income_usa   votes  user_rating  critics_reviews
# 0          32391374  448799        563.0            349.0
# 1          72082998  268631        700.0            514.0
# 2             14616    1152         26.0              2.0
# 3              5152     143         17.0              9.0
# 4             54702    5938         34.0             24.0
